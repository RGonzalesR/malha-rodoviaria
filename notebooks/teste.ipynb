# %%
import osmnx as ox

# Baixar a rede viária para veículos em São Carlos, SP
G = ox.graph_from_place('São Paulo, Brazil', network_type='drive')

# Visualizar a rede
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
